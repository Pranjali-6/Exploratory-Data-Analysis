# %% [markdown]
# # Project Objective

# %% [markdown]
# ## Exploratory Data Analysis on Hotel Booking

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
sns.set()
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv("hotel_booking.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %% [markdown]
# ## dropping irrelavent columns

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(["name","email","phone-number","credit_card"],axis=1,inplace=True)

# %%
df.reset_index()
# Out:
#          index         hotel  is_canceled  lead_time  arrival_date_year  \
# 0            0  Resort Hotel            0        342               2015
# 1            1  Resort Hotel            0        737               2015
# 2            2  Resort Hotel            0          7               2015
# 3            3  Resort Hotel            0         13               2015
# 4            4  Resort Hotel            0         14               2015
# ...        ...           ...          ...        ...                ...
# 119385  119385    City Hotel            0         23               2017
# 119386  119386    City Hotel            0        102               2017
# 119387  119387    City Hotel            0         34               2017
# 119388  119388    City Hotel            0        109               2017
# 119389  119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# ...

# %% [markdown]
# ## Understanding dataset

# %%
df.shape
# Out:
# (119390, 32)

# %%
pd.set_option('display.max_columns',32)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
df['hotel'].value_counts() ## not a balanced data set
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df['meal'].value_counts() 
#undefined/SC - no meal package
#BB - bed& breakfast
#HB - Half Board( breakfast + 1 meal)
#FB - Full Board ( 3 meals)
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
df['market_segment'].value_counts()
# TA - travel Agent
# TO - Tour Operator
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
df['distribution_channel'].value_counts()
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
df['deposit_type'].value_counts()
# Majority No deposit
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
df['customer_type'].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %%
df['total_of_special_requests'].value_counts()
# Out:
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: total_of_special_requests, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df,x='hotel')
# Out:
# <AxesSubplot: xlabel='hotel', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df,x='is_canceled',hue='is_repeated_guest')
# Out:
# <AxesSubplot: xlabel='is_canceled', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df,x='hotel',hue='is_canceled')
# Out:
# <AxesSubplot: xlabel='hotel', ylabel='count'>

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop('company',axis=1,inplace=True)

# %%
df.fillna(0,inplace=True)
#replace null values with 0

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
df['meal'].replace('Undefined','SC',inplace=True)

# %%
df['meal'].value_counts()
# Out:
# BB    92310
# HB    14463
# SC    11819
# FB      798
# Name: meal, dtype: int64

# %%
df['total_guest'] = df['adults']+df['babies']+df['children']

# %%
# delete rows with total guest = 0 
df = df[df['total_guest']>0]

# %%
df = df.reset_index()

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119205    City Hotel            0         23               2017
# 119206    City Hotel            0        102               2017
# 119207    City Hotel            0         34               2017
# 119208    City Hotel            0        109               2017
# 119209    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data = df.copy()

# %% [markdown]
# ## Where do guests come from?

# %%
data1 = data['country'].value_counts().reset_index()
data1.columns = ['country','no_of_guests']
data1['no_of_guests'].sum()
# Out:
# 119210

# %%
data1.shape
# Out:
# (178, 2)

# %%
plt.figure(figsize=(10,10))
plt.pie(x= data1['no_of_guests'],labels=data1['country'],textprops={'fontsize': 30}, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### People from all over the world are staying in this hotel. 52% people are from Portugal, Great Britain and France.

# %% [markdown]
# ## Avg rate of hotels not cancelled

# %%
data = data[data['adr']>0]

# %%
data['avg_adr'] = data['adr']/(data['adults']+data['children'])

# %%
resort = data[(data['hotel'] == 'Resort Hotel') & (data['is_canceled'] == 0)]
city = data[(data['hotel'] == 'City Hotel') & (data['is_canceled'] == 0)]

# %%
resort_hotel = resort.groupby(['arrival_date_month'])['avg_adr'].mean().reset_index()
#resort_hotel

# %%
city_hotel = city.groupby(['arrival_date_month'])['avg_adr'].mean().reset_index()
#city_hotel

# %%
final = resort_hotel.merge(city_hotel,on = 'arrival_date_month')
final.columns = ['month','price_for_resort','price_for_city_hotel']
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         44.725812             59.531546
# 1      August         84.463704             58.879670
# 2    December         39.366854             49.842786
# 3    February         31.555989             52.042529
# 4     January         32.115826             52.565578
# 5        July         71.516237             58.322598
# 6        June         57.360025             67.340285
# 7       March         34.861258             53.320455
# 8         May         43.296176             71.442346
# 9    November         30.894532             58.654831
# 10    October         36.170182             63.382922
# 11  September         50.979062             68.694085

# %%
sort_order=['January','February','March','April','May','June','July','August','September','October','November','December']
final.index=pd.CategoricalIndex(final['month'],categories=sort_order,ordered=True)
final=final.sort_index().reset_index(drop=True)
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0     January         32.115826             52.565578
# 1    February         31.555989             52.042529
# 2       March         34.861258             53.320455
# 3       April         44.725812             59.531546
# 4         May         43.296176             71.442346
# 5        June         57.360025             67.340285
# 6        July         71.516237             58.322598
# 7      August         84.463704             58.879670
# 8   September         50.979062             68.694085
# 9     October         36.170182             63.382922
# 10   November         30.894532             58.654831
# 11   December         39.366854             49.842786

# %%
plt.figure(figsize=(10,10))
plt.plot(final['month'],final['price_for_city_hotel'])
plt.plot(final['month'],final['price_for_resort'])
plt.xlabel('Hotel')
plt.ylabel('Avg_adr')
plt.rcParams.update({'font.size': 50})
plt.legend(['City Hotel','Resort Hotel'])
plt.show()

# %% [markdown]
# ADR for resort hotel is very high in the months of june, july, august, september.
# Duing this time city hotel prices are low.

# %%
data['total_stay'] = data['stays_in_weekend_nights'] + data['stays_in_week_nights']
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119205    City Hotel            0         23               2017
# 119206    City Hotel            0        102               2017
# 119207    City Hotel            0         34               2017
# 119208    City Hotel            0        109               2017
# 119209    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=data, x ='reservation_status',hue='hotel')
# Out:
# <AxesSubplot: xlabel='reservation_status', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=data,x='required_car_parking_spaces',hue='is_canceled')
# Out:
# <AxesSubplot: xlabel='required_car_parking_spaces', ylabel='count'>

# %%
x = data['required_car_parking_spaces'].value_counts()
plt.figure(figsize=(10,10))
plt.pie(x,labels=[0,1,2,3,8],textprops={'fontsize': 30}, autopct='%1.1f%%')
plt.show()

# %%
## 93.8% people do not require any car parking

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=data,x='market_segment',hue='is_canceled')
# Out:
# <AxesSubplot: xlabel='market_segment', ylabel='count'>

# %%
# Online TA & Offline TA/TO should improve cancelation policies. 
# More focus sholud be given to booking through Aviation, Corporate and Direct.

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=data,x='reserved_room_type')
# Out:
# <AxesSubplot: xlabel='reserved_room_type', ylabel='count'>

# %%
## Room type A is most prefered by guests

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=data,x='deposit_type')
# Out:
# <AxesSubplot: xlabel='deposit_type', ylabel='count'>
